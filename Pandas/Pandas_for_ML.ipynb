# %%
#import library
import pandas as pd

# %%
#empty
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city = ['Berlin', 'Elrangen', 'Zurich']
city
# Out:
# ['Berlin', 'Elrangen', 'Zurich']

# %%
df = pd.DataFrame(city)
df
# Out:
#           0
# 0    Berlin
# 1  Elrangen
# 2    Zurich

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(city)
# Out:
# list

# %%
row, col=df.shape

# %%
row
# Out:
# 3

# %%
col
# Out:
# 1

# %%
df.shape
# Out:
# (3, 1)

# %%
df
# Out:
#           0
# 0    Berlin
# 1  Elrangen
# 2    Zurich

# %%
df = pd.DataFrame(city, columns=['city_in_Europe'], index=['c1','c2','c3'])
df
# Out:
#    city_in_Europe
# c1         Berlin
# c2       Elrangen
# c3         Zurich

# %%
city2 = ['Dortmund','Paris','Portsdam']
df2 = pd.DataFrame(zip(city,city2), columns=['city1','city2'])
df2
# Out:
#       city1     city2
# 0    Berlin  Dortmund
# 1  Elrangen     Paris
# 2    Zurich  Portsdam

# %%
df2.shape
# Out:
# (3, 2)

# %%
city3 = [['A', 'B', 'C'],['D', 'E', 'F']]
df3 = pd.DataFrame(city3, columns=['c1','c2','c3'])
df3
#
# Out:
#   c1 c2 c3
# 0  A  B  C
# 1  D  E  F

# %%
df3.shape
# Out:
# (2, 3)

# %%
city4 = [city, city2]
df4 = pd.DataFrame(city4)
df4
# Out:
#           0         1         2
# 0    Berlin  Elrangen    Zurich
# 1  Dortmund     Paris  Portsdam

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
path ="/content/drive/MyDrive/Dataset/Pandas Practice/data.csv"
df=pd.read_csv(path)
df.head(20)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# ...

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
print(df.columns)
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df[["Pulse"]]
# Out:
#     Pulse
# 0     110
# 1     117
# 2     103
# 3     109
# 4     117
# 5     102
# 6     110
# 7     104
# 8     109
# 9      98
# 10    103
# 11    100
# 12    100
# 13    106
# 14    104
# 15     98
# 16     98
# 17    100
# 18     90
# 19    103
# 20     97
# 21    108
# 22    100
# 23    130
# 24    105
# 25    102
# 26    100
# 27     92
# 28    103
# 29    100
# 30    102
# 31     92

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
#subseting rows
df['Pulse']>100
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21     True
# 22    False
# 23     True
# 24     True
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# Name: Pulse, dtype: bool

# %%
df[df['Pulse']>100]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 10        60  '2020/12/11'    103       147     329.3
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 19        60  '2020/12/19'    103       123     323.0
# 21        60  '2020/12/21'    108       131     364.2
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# ...

# %%
df[df['Date']=='\'2020/12/05\'']
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 4        45  '2020/12/05'    117       148     406.0

# %%
df[df['Date'].isin(['\'2020/12/05\''])]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 4        45  '2020/12/05'    117       148     406.0
