# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as splt
import seaborn

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("credit card taiwan.csv")

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1  24.0      2      2     -1
# 1          2   120000.0    2          2         2  26.0     -1      2      0
# 2          3    90000.0    2          2         2   NaN      0      0      0
# 3          4    50000.0    2          2         1   NaN      0      0      0
# 4          5    50000.0    1          2         1  57.0     -1      0     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.0      0      0      0
# 29996  29997   150000.0    1          3         2  43.0     -1     -1     -1
# 29997  29998    30000.0    1          2         2  37.0      4      3      2
# 29998  29999    80000.0    1          3         1  41.0      1     -1      0
# 29999  30000    50000.0    1          2         1  46.0      0      0      0
#
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           2
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
missing_value = df.AGE.mean()

# %%
df.AGE = df.AGE.fillna(missing_value)

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
x = df.drop(['default.payment.next.month'], axis =1)

# %%
x
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE        AGE  PAY_0  PAY_2  \
# 0          1    20000.0    2          2         1  24.000000      2      2
# 1          2   120000.0    2          2         2  26.000000     -1      2
# 2          3    90000.0    2          2         2  35.485499      0      0
# 3          4    50000.0    2          2         1  35.485499      0      0
# 4          5    50000.0    1          2         1  57.000000     -1      0
# ...      ...        ...  ...        ...       ...        ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.000000      0      0
# 29996  29997   150000.0    1          3         2  43.000000     -1     -1
# 29997  29998    30000.0    1          2         2  37.000000      4      3
# 29998  29999    80000.0    1          3         1  41.000000      1     -1
# 29999  30000    50000.0    1          2         1  46.000000      0      0
#
# ...

# %%
y = df['default.payment.next.month']

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %% [markdown]
# # Spliting Train and Test data

# %%
from sklearn.model_selection import train_test_split 
from sklearn.svm import SVC

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size = 0.25, random_state = 1)

# %%
xtrain
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 26340  26341   150000.0    2          1         2  26.0      0      0      2
# 3877    3878    50000.0    2          2         2  23.0      0      0      0
# 27081  27082    80000.0    1          2         2  31.0      0      0      0
# 5440    5441   120000.0    2          2         2  39.0      0      0      2
# 22164  22165   150000.0    2          1         3  30.0      1     -1      2
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 17289  17290   170000.0    2          3         1  40.0      1      2      0
# 5192    5193   330000.0    2          1         1  41.0     -1     -1     -2
# 12172  12173    50000.0    1          2         2  22.0      0      0      0
# 235      236    80000.0    1          1         2  35.0     -1     -1     -1
# 29733  29734   300000.0    1          2         1  37.0     -2     -2     -1
#
# ...

# %%
model = SVC()

# %%
model.fit(xtrain, ytrain)
# Out:
# SVC()

# %%
model.score(xtest, ytest)
# Out:
# 0.7776

# %% [markdown]
# ## Testing with other classification algorithm

# %% [markdown]
# ### Trying with Random Forest algorithm

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rclf = RandomForestClassifier()

# %%
Rclf.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
Rclf.score(xtest, ytest)
# Out:
# 0.8141333333333334

# %% [markdown]
# ### Trying with Decision Tree algorithm

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Dclf = DecisionTreeClassifier()

# %%
Dclf.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
Dclf.score(xtest, ytest)
# Out:
# 0.7246666666666667

# %% [markdown]
# # Let's try with Naive Bayes Classifier

# %% [markdown]
# ### First trying with Gaussian

# %%
from sklearn.naive_bayes import GaussianNB

# %%
GNB = GaussianNB()

# %%
GNB.fit(xtrain, ytrain)
# Out:
# GaussianNB()

# %%
GNB.score(xtest, ytest)
# Out:
# 0.3848

# %% [markdown]
# ### Now trying with Bernoulli

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
BNB = BernoulliNB()

# %%
BNB.fit(xtrain, ytrain)
# Out:
# BernoulliNB()

# %%
BNB.score(xtest, ytest)
# Out:
# 0.7713333333333333

# %% [markdown]
# ### Now trying with Multinomial

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
MNB = MultinomialNB()

# %%
MNB.fit(xtrain, ytrain)  # so skip Multinomial NB if there is any negative value. Multinomial NB does not work with negative value. that is why its showing error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 MNB.fit(xtrain, ytrain)  # so skip Multinomial NB if there is any negative value. Multinomial NB does not work with negative value. that is why its showing error
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\naive_bayes.py:772, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     770 n_classes = Y.shape[1]
# ...

# %%
MNB.score(xtest, ytest)
