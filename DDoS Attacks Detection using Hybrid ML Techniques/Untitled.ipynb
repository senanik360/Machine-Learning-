# %%
import pandas as pd
# Create a DataFrame with the detailed descriptions and roles
data = {
    'No': list(range(1, 46)),
    'Name': ['Init_Win_bytes_forward', 'act_data_pkt_fwd', 'Subflow Fwd Bytes',
             'Avg Fwd Segment Size', 'Fwd Packet Length Max', 'Bwd Packet Length Max',
             'Fwd IAT Std', 'Fwd Packet Length Mean', 'Total Length of Fwd Packets',
             'Fwd IAT Mean', 'Subflow Fwd Packets', 'Fwd Packet Length Std', 'Fwd IAT Total',
             'Fwd Header Length', 'Packet Length Variance', 'Average Packet Size', 'Bwd Header Length',
             'Total Length of Bwd Packets', 'Avg Bwd Segment Size', 'Max Packet Length', 'Fwd IAT Max',
             'Destination Port', 'Flow IAT Std', 'Subflow Bwd Bytes', 'Fwd Header Length.1', 
             'Bwd Packet Length Mean', 'Init_Win_bytes_backward', 'Bwd Packet Length Std', 'Bwd Packets/s',
             'Bwd Packet Length Min', 'Total Backward Packets', 'Packet Length Mean', 'Subflow Bwd Packets',
             'Down/Up Ratio', 'Packet Length Std', 'Flow Duration', 'Bwd IAT Max', 'Bwd IAT Total', 
             'Fwd IAT Min', 'Bwd IAT Std', 'min_seg_size_forward', 'Flow IAT Max', 'Fwd Packets/s', 
             'Min Packet Length', 'Fwd Packet Length Min'],
    'Description': [
        'Initial window size in bytes for the forward direction.',
        'Number of actual data packets sent in the forward direction.',
        'Number of bytes in the forward direction for a subflow.',
        'Average size of the forward segments.',
        'Maximum length of packets in the forward direction.',
        'Maximum length of packets in the backward direction.',
        'Standard deviation of the inter-arrival time between packets in the forward direction.',
        'Mean length of packets in the forward direction.',
        'Total length of all packets in the forward direction.',
        'Mean inter-arrival time between packets in the forward direction.',
        'Number of packets in the forward direction for a subflow.',
        'Standard deviation of the packet lengths in the forward direction.',
        'Total inter-arrival time between packets in the forward direction.',
        'Header length of packets in the forward direction.',
        'Variance in the length of packets.',
        'Average size of packets.',
        'Header length of packets in the backward direction.',
        'Total length of all packets in the backward direction.',
        'Average size of the backward segments.',
        'Maximum length of packets in the flow.',
        'Maximum inter-arrival time between packets in the forward direction.',
        'Port number of the destination.',
        'Standard deviation of the inter-arrival time between packets in the flow.',
        'Number of bytes in the backward direction for a subflow.',
        'Duplicate column for forward header length.',
        'Mean length of packets in the backward direction.',
        'Initial window size in bytes for the backward direction.',
        'Standard deviation of the packet lengths in the backward direction.',
        'Number of backward packets per second.',
        'Minimum length of packets in the backward direction.',
        'Total number of packets in the backward direction.',
        'Mean length of packets in the flow.',
        'Number of packets in the backward direction for a subflow.',
        'Ratio of downlink to uplink traffic.',
        'Standard deviation of the packet lengths in the flow.',
        'Total duration of the flow.',
        'Maximum inter-arrival time between packets in the backward direction.',
        'Total inter-arrival time between packets in the backward direction.',
        'Minimum inter-arrival time between packets in the forward direction.',
        'Standard deviation of the inter-arrival time between packets in the backward direction.',
        'Minimum segment size observed in the forward direction.',
        'Maximum inter-arrival time between packets in the flow.',
        'Number of forward packets per second.',
        'Minimum length of packets in the flow.',
        'Minimum length of packets in the forward direction.'
    ],
    'Rol': ['Role not provided' for _ in range(45)]
}

description_df = pd.DataFrame(data)
#tools.display_dataframe_to_user(name="Detailed Description Table", dataframe=description_df)
description_df.head(48)
# Out:
#     No                         Name  \
# 0    1       Init_Win_bytes_forward
# 1    2             act_data_pkt_fwd
# 2    3            Subflow Fwd Bytes
# 3    4         Avg Fwd Segment Size
# 4    5        Fwd Packet Length Max
# 5    6        Bwd Packet Length Max
# 6    7                  Fwd IAT Std
# 7    8       Fwd Packet Length Mean
# 8    9  Total Length of Fwd Packets
# 9   10                 Fwd IAT Mean
# 10  11          Subflow Fwd Packets
# 11  12        Fwd Packet Length Std
# 12  13                Fwd IAT Total
# 13  14            Fwd Header Length
# 14  15       Packet Length Variance
# 15  16          Average Packet Size
# 16  17            Bwd Header Length
# 17  18  Total Length of Bwd Packets
# 18  19         Avg Bwd Segment Size
# 19  20            Max Packet Length
# 20  21                  Fwd IAT Max
# 21  22             Destination Port
# 22  23                 Flow IAT Std
# 23  24            Subflow Bwd Bytes
# 24  25          Fwd Header Length.1
# ...
